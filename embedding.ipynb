# %%
import pandas as pd
from dotenv import load_dotenv
import os

from langchain_community.document_loaders import CSVLoader
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS

# %%
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    raise ValueError("❌ GOOGLE_API_KEY not found in .env file")
else:
    print("✅ API key loaded successfully")
# Out:
# ✅ API key loaded successfully

# %%
csv_path = "data/10final_merged_realestate_data.csv"  
loader = CSVLoader(file_path=csv_path)
documents = loader.load()

print(f"✅ Loaded {len(documents)} documents from CSV")
# Out:
# ✅ Loaded 83 documents from CSV

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

# %%
print(documents[0])
# Out:
# page_content='unique_property_id: cmff8vfoq0013vxp7h3onmg46
# id_x: cmf53kkzy000fvcu8tx8jwjmr
# projectType: RESIDENTIAL
# projectName: Ashwini
# projectCategory: STANDALONE
# slug: luxury-ashwini-ashoknagar-chembur-mumbai-675058
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-28 00:00:00
# id_y: cmf53kl01000nvcu8ibut7fka
# landmark: Babys school
# fullAddress: Mumbai chembur
# pincode: 411017
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmf53kkzz000ivcu89r5399s4
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757584023815-67012c27580e3e23.jpg
# carpetArea: 123.0
# price: 11111111
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1756971672464-1e5179453b5df91d.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Ashwini and type :1BHK. Located at : Mumbai chembur , near luxury-ashwini-ashoknagar-chembur-mumbai-675058 , having landmark :Babys school Property Type: . Price: Rs11111111. having Area or carpet area: 123.0 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 0}

# %%
import time
from tqdm import tqdm

# Process documents in smaller batches with rate limiting
batch_size = 10  # Adjust this based on your quota
delay_between_batches = 15  # seconds

print(f"Processing {len(documents)} documents in batches of {batch_size}...")

# Split documents into batches
all_embeddings = []
for i in tqdm(range(0, len(documents), batch_size)):
    batch = documents[i:i + batch_size]
    
    try:
        # Create FAISS index from batch
        if i == 0:
            # First batch - create new index
            vectordb = FAISS.from_documents(batch, embeddings)
        else:
            # Subsequent batches - merge with existing index
            batch_db = FAISS.from_documents(batch, embeddings)
            vectordb.merge_from(batch_db)
        
        print(f"✅ Processed batch {i//batch_size + 1}/{(len(documents)-1)//batch_size + 1}")
        
        # Rate limiting - wait between batches
        if i + batch_size < len(documents):
            time.sleep(delay_between_batches)
            
    except Exception as e:
        print(f"Error processing batch at index {i}: {e}")
        print(f"Try reducing batch_size or increasing delay_between_batches")
        raise

# Save the vector store
vectordb.save_local("faiss_realestate_index")
print("✅ FAISS vector store created and saved as 'faiss_realestate_index'")
# Out:
# Processing 83 documents in batches of 10...
#   0%|          | 0/9 [00:00<?, ?it/s]
# ✅ Processed batch 1/9
#  11%|█         | 1/9 [00:16<02:12, 16.53s/it]
# ✅ Processed batch 2/9
#  22%|██▏       | 2/9 [00:33<01:56, 16.63s/it]
# ✅ Processed batch 3/9
#  33%|███▎      | 3/9 [00:49<01:40, 16.67s/it]
# ✅ Processed batch 4/9
#  44%|████▍     | 4/9 [01:06<01:23, 16.61s/it]
# ✅ Processed batch 5/9
#  56%|█████▌    | 5/9 [01:23<01:06, 16.63s/it]
# ✅ Processed batch 6/9
#  67%|██████▋   | 6/9 [01:39<00:49, 16.65s/it]
# ✅ Processed batch 7/9
#  78%|███████▊  | 7/9 [01:56<00:33, 16.65s/it]
# ✅ Processed batch 8/9
# 100%|██████████| 9/9 [02:29<00:00, 16.65s/it]
# ✅ Processed batch 9/9
# ✅ FAISS vector store created and saved as 'faiss_realestate_index'

# %%
vectordb = FAISS.from_documents(documents, embeddings)
vectordb.save_local("faiss_realestate_index")

print("✅ FAISS vector store created and saved as 'faiss_realestate_index'")

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100,
    length_function=len
)

chunks = text_splitter.split_documents(documents)
print(f"Split the documents into {len(chunks)} chunks.")

SOURCE_DIR   = Path("docs")             # put your files here
INDEX_DIR    = Path("chroma_db_1")        # will be created if missing
COLLECTION   = "kb_collection"
EMBED_MODEL  = "gemini-embedding-001"

embeddings = GoogleGenerativeAIEmbeddings(model=EMBED_MODEL)
vectordb   = FAISS.from_documents(
    documents         = chunks,
    embedding         = embeddings,
    persist_directory = str(INDEX_DIR),
    collection_name   = COLLECTION,
)
# Out:
# Split the documents into 175 chunks.
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\langchain_google_genai\embeddings.py:273, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     272 try:
# --> 273     result = self.client.batch_embed_contents(
#     274         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     275     )
#     276 except Exception as e:
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1438, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1437 # Send the request.
# -> 1438 response = rpc(
#    1439     request,
#    1440     retry=retry,
#    1441     timeout=timeout,
#    1442     metadata=metadata,
#    1443 )
#    1445 # Done; return the response.
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[13], line 18
#      15 EMBED_MODEL  = "gemini-embedding-001"
#      17 embeddings = GoogleGenerativeAIEmbeddings(model=EMBED_MODEL)
# ---> 18 vectordb   = FAISS.from_documents(
#      19     documents         = chunks,
#      20     embedding         = embeddings,
#      21     persist_directory = str(INDEX_DIR),
#      22     collection_name   = COLLECTION,
#      23 )
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\langchain_core\vectorstores\base.py:805, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     802     if any(ids):
#     803         kwargs["ids"] = ids
# --> 805 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File d:\couses\project\realestate_property_rag\venv\Lib\site-packages\langchain_google_genai\embeddings.py:278, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     276     except Exception as e:
#     277         msg = f"Error embedding content: {e}"
# --> 278         raise GoogleGenerativeAIError(msg) from e
#     279     embeddings.extend([list(e.values) for e in result.embeddings])
#     280 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# ]

# %%
# Load FAISS index
db = FAISS.load_local("faiss_realestate_index", embeddings, allow_dangerous_deserialization=True)

# Example query
query = "3BHK flats with lift in Yashvant Seth Jadhav Marg"
results = db.similarity_search(query, k=3)

for i, res in enumerate(results, 1):
    print(f"\n🔹 Result {i}:")
    print(res)
# Out:
# 🔹 Result 1:
# page_content='unique_property_id: cmfdmdqmt000hvc90cqvdwrq7
# id_x: cmfdmdqmq0008vc90svu2sfto
# projectType: RESIDENTIAL
# projectName: Antriksh
# projectCategory: STANDALONE
# slug: luxury-antriksh-somwarpeth-camp-pune-997560
# projectAge:
# projectSummary: _
# possessionDate:
# id_y: cmfdmdqmu000jvc90b6auuc6b
# landmark: Station Road Saraswat Colony
# fullAddress: CTS NO 391, Station Rd, opp. Zilla Parishad, Mangalwar Peth, Somwar Peth, Pune, Maharashtra 411011
# pincode: 411011
# propertyCategory: RESIDENTIAL
# type: 3BHK
# configurationId: cmfdmdqmt000gvc90h6gcwpga
# bathrooms: 3
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757486991499-74fa17a4c97985e2.jpg
# carpetArea: 1095.0
# price: 22900000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757486991505-2373b8e162de669f.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Antriksh and type :3BHK. Located at : CTS NO 391, Station Rd, opp. Zilla Parishad, Mangalwar Peth, Somwar Peth, Pune, Maharashtra 411011 , near luxury-antriksh-somwarpeth-camp-pune-997560 , having landmark :Station Road Saraswat Colony Property Type: . Price: Rs22900000. having Area or carpet area: 1095.0 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 46}
#
# 🔹 Result 2:
# page_content='unique_property_id: cmfawdrnr000evc18jwvlery4
# id_x: cmfawdrno0007vc18l0fm0z2j
# projectType: RESIDENTIAL
# projectName: Gurukripa
# projectCategory: COMPLEX
# slug: gurukripa-ashoknagar-chembur-mumbai-086047
# projectAge:
# projectSummary: _
# possessionDate:
# id_y: cmfawdrnt000kvc18h3j7e93j
# landmark: Sindhi Society
# fullAddress: Sindhi Society, Near Swami Vivekanand Jr College, Chembur, Mumbai Harbour, Mumbai
# pincode: 400071
# propertyCategory: RESIDENTIAL
# type: 3BHK
# configurationId: cmfawdrnr000dvc188hupv4yy
# bathrooms: 3
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757322391158-41329b8304cff17d.jpg
# carpetArea: 893.08
# price: 29000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757322391167-19d3844213de86cb.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Gurukripa and type :3BHK. Located at : Sindhi Society, Near Swami Vivekanand Jr College, Chembur, Mumbai Harbour, Mumbai , near gurukripa-ashoknagar-chembur-mumbai-086047 , having landmark :Sindhi Society Property Type: . Price: Rs29000000. having Area or carpet area: 893.08 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 6}
#
# 🔹 Result 3:
# page_content='unique_property_id: cmfawdrnr000fvc18af74elnu
# id_x: cmfawdrno0007vc18l0fm0z2j
# projectType: RESIDENTIAL
# projectName: Gurukripa
# projectCategory: COMPLEX
# slug: gurukripa-ashoknagar-chembur-mumbai-086047
# projectAge:
# projectSummary: _
# possessionDate:
# id_y: cmfawdrnt000kvc18h3j7e93j
# landmark: Sindhi Society
# fullAddress: Sindhi Society, Near Swami Vivekanand Jr College, Chembur, Mumbai Harbour, Mumbai
# pincode: 400071
# propertyCategory: RESIDENTIAL
# type: 3BHK
# configurationId: cmfawdrnr000dvc188hupv4yy
# bathrooms: 3
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757322391179-7f2bff943c2805a5.jpg
# carpetArea: 918.27
# price: 29000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757322391188-7b25319224e8a812.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Gurukripa and type :3BHK. Located at : Sindhi Society, Near Swami Vivekanand Jr College, Chembur, Mumbai Harbour, Mumbai , near gurukripa-ashoknagar-chembur-mumbai-086047 , having landmark :Sindhi Society Property Type: . Price: Rs29000000. having Area or carpet area: 918.27 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 7}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

query = "Which projects have  apartments near Babys school?"

results = db.similarity_search(query, k=3)

for i, res in enumerate(results, 1):
    print(f"\n🔹 Result {i}:")
    print(res)


prompt = f"""
Use the following property data to answer the user's query.
Return factual, concise answers.
and identify each property by its unique_property_ID i.e the first column in the database.
results:
{results}

Question:
{query}
and if no projects are found, respond with "No projects found."or can list only the relevant projects.
"""

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",  
    google_api_key=api_key
)
response = model.invoke(prompt)
print(response)
# Out:
# 🔹 Result 1:
# page_content='unique_property_id: cmff8vfoq0013vxp7h3onmg46
# id_x: cmf53kkzy000fvcu8tx8jwjmr
# projectType: RESIDENTIAL
# projectName: Ashwini
# projectCategory: STANDALONE
# slug: luxury-ashwini-ashoknagar-chembur-mumbai-675058
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-28 00:00:00
# id_y: cmf53kl01000nvcu8ibut7fka
# landmark: Babys school
# fullAddress: Mumbai chembur
# pincode: 411017
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmf53kkzz000ivcu89r5399s4
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757584023815-67012c27580e3e23.jpg
# carpetArea: 123.0
# price: 11111111
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1756971672464-1e5179453b5df91d.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Ashwini and type :1BHK. Located at : Mumbai chembur , near luxury-ashwini-ashoknagar-chembur-mumbai-675058 , having landmark :Babys school Property Type: . Price: Rs11111111. having Area or carpet area: 123.0 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 0}
#
# 🔹 Result 2:
# page_content='unique_property_id: cmff8vjd4001dvxp7tq21djvf
# id_x: cmf53kkzy000fvcu8tx8jwjmr
# projectType: RESIDENTIAL
# projectName: Ashwini
# projectCategory: STANDALONE
# slug: luxury-ashwini-ashoknagar-chembur-mumbai-675058
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-28 00:00:00
# id_y: cmf53kl01000nvcu8ibut7fka
# landmark: Babys school
# fullAddress: Mumbai chembur
# pincode: 411017
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmf53kl00000kvcu86ivy65di
# bathrooms: 0
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1756971672464-419924a4c5c28823.jpg
# carpetArea: 456.0
# price: 22222222
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1756971672464-7c8c73119cb2047b.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Ashwini and type :2BHK. Located at : Mumbai chembur , near luxury-ashwini-ashoknagar-chembur-mumbai-675058 , having landmark :Babys school Property Type: . Price: Rs22222222. having Area or carpet area: 456.0 sq meter. and also _ !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 1}
#
# 🔹 Result 3:
# page_content='unique_property_id: cmfp02t4b002dvxxu826dader
# id_x: cmff8swbm0001vxp7pe3neibi
# projectType: RESIDENTIAL
# projectName: testing
# projectCategory: STANDALONE
# slug: testing-modelcolony-shivajinagar-pune-301013
# projectAge: 11.0
# projectSummary: sdfghjhgfdfghjgfdfghgfgh
# possessionDate:
# id_y: cmff8swbn0007vxp7bhj7cmqv
# landmark: sdfgb
# fullAddress: asdfgh
# pincode: 123456
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmfozzj19001rvxxuloxiehen
# bathrooms: 99
# balcony: 987.0
# furnishedType: SEMI_FURNISHED
# furnishingType: ["KITCHEN_APPLIANCES","BASIC_FURNITURE"]
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174963753-1d59b6ee8bc63eff.jpg
# carpetArea: 9.0
# price: 980000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174963765-07ee6ee92139cc03.jpeg"]
# lift: 0
# ready_to_move: 1
# context: Project Name: testing and type :2BHK. Located at : asdfgh , near testing-modelcolony-shivajinagar-pune-301013 , having landmark :sdfgb Property Type: . Price: Rs980000000. having Area or carpet area: 9.0 sq meter. and also sdfghjhgfdfghjgfdfghgfgh !.' metadata={'source': 'data/10final_merged_realestate_data.csv', 'row': 67}
# content='* **Ashwini** (unique_property_id: cmff8vfoq0013vxp7h3onmg46)\n* **Ashwini** (unique_property_id: cmff8vjd4001dvxp7tq21djvf)' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'} id='lc_run--36169174-c697-4831-9eef-774155d7a930-0' usage_metadata={'input_tokens': 1893, 'output_tokens': 64, 'total_tokens': 1957, 'input_token_details': {'cache_read': 0}}

# %%
db = FAISS.load_local("faiss_realestate_index", embeddings, allow_dangerous_deserialization=True)

# %%
from langchain_core.prompts import ChatPromptTemplate
query = "Which projects have  apartments near Yashvant Seth Jadhav Marg ?"
results = db.similarity_search(query, k=5)

print(f"🔍 Retrieved {len(results)} most relevant property entries.\n")

for i, res in enumerate(results, 1):
    print(f"🔹 Result {i} Preview:")
    print(res.page_content[:], "...\n")


prompt_template = ChatPromptTemplate.from_template("""
You are a Real Estate Expert Assistant helping the user find matching properties.

You will be given:
1. Retrieved property data (from a structured CSV embedding)
2. A user query

Your task:
- Identify which properties match **all** conditions in the query.
- Mention their `unique_property_id` and key details (projectName, location, price,area,pincode,type amenities if available).
- If any part of the user query is not satisfied (e.g., "near Babys school" missing or unclear), explicitly say so under **Unmatched Points**.
- Never hallucinate or assume data not present in the retrieved content.
- If nothing matches, say **"No projects found."**

---
🧾 Retrieved Property Data:
{context}

💬 User Query:
{question}

Now provide a structured answer:
1. ✅ Matching Projects (ID + key info)
2. ⚠️ Unmatched Points (if any)
3. 💡 Explanation (why missing, limitations, etc.)
""")

context = "\n\n".join([doc.page_content for doc in results])

final_prompt = prompt_template.format(context=context, question=query)

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",  # fast, cost-efficient
    google_api_key=api_key,
    temperature=0.2
)
response = model.invoke(final_prompt)


print(" FINAL ANSWER:")
print(response.content)


print("\n CONTEXT USED:")
for i, doc in enumerate(results, 1):
    print(f"\nDocument {i}:\n", doc.page_content[:])
# Out:
# 🔍 Retrieved 5 most relevant property entries.
#
# 🔹 Result 1 Preview:
# unique_property_id: cmfaycwy9003bvc189xf97r7w
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712593-25cd2d9a5765be22.jpg
# carpetArea: 354.0
# price: 790000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712594-cd33c56e7db9cd37.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs790000. having Area or carpet area: 354.0 sq meter. and also _ !. ...
#
# 🔹 Result 2 Preview:
# unique_property_id: cmfaycwy9003cvc181yx3c5gf
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 0.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712597-accd128a6ea12d10.jpg
# carpetArea: 391.0
# price: 880000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712598-d2ac8b8887119ad8.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs880000. having Area or carpet area: 391.0 sq meter. and also _ !. ...
#
# 🔹 Result 3 Preview:
# unique_property_id: cmfaycwy9003evc186uhex90a
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmfaycwy9003dvc1853ic14wb
# bathrooms: 2
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712599-4bd849d13fb20425.jpg
# carpetArea: 536.0
# price: 12000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712607-8e031215d719e572.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :2BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs12000000. having Area or carpet area: 536.0 sq meter. and also _ !. ...
#
# 🔹 Result 4 Preview:
# unique_property_id: cmfaycwy9003avc18vwkotg8q
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712590-57c98e762d3e95c3.jpg
# carpetArea: 379.0
# price: 850000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712591-aa79bad30786e10c.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs850000. having Area or carpet area: 379.0 sq meter. and also _ !. ...
#
# 🔹 Result 5 Preview:
# unique_property_id: cmfaycwy9003fvc1859euhuy7
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmfaycwy9003dvc1853ic14wb
# bathrooms: 2
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712608-05900f06f63a6dfa.jpg
# carpetArea: 650.0
# price: 14000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712608-e94b60550c5c2690.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :2BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs14000000. having Area or carpet area: 650.0 sq meter. and also _ !. ...
#
# 🧠 FINAL ANSWER:
# ✅ Matching Projects:
#
# *   **unique_property_id**: cmfaycwy9003bvc189xf97r7w
#     *   **projectName**: Om makarand heights
#     *   **location**: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
#     *   **price**: 790000
#     *   **area**: 354.0 sq meter
#     *   **pincode**: 400075
#     *   **type**: 1BHK
#     *   **amenities**: Not specified
#
# *   **unique_property_id**: cmfaycwy9003cvc181yx3c5gf
#     *   **projectName**: Om makarand heights
#     *   **location**: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
#     *   **price**: 880000
#     *   **area**: 391.0 sq meter
#     *   **pincode**: 400075
#     *   **type**: 1BHK
#     *   **amenities**: Not specified
#
# *   **unique_property_id**: cmfaycwy9003evc186uhex90a
#     *   **projectName**: Om makarand heights
#     *   **location**: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
#     *   **price**: 12000000
#     *   **area**: 536.0 sq meter
#     *   **pincode**: 400075
#     *   **type**: 2BHK
#     *   **amenities**: Not specified
#
# *   **unique_property_id**: cmfaycwy9003avc18vwkotg8q
#     *   **projectName**: Om makarand heights
#     *   **location**: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
#     *   **price**: 850000
#     *   **area**: 379.0 sq meter
#     *   **pincode**: 400075
#     *   **type**: 1BHK
#     *   **amenities**: Not specified
#
# *   **unique_property_id**: cmfaycwy9003fvc1859euhuy7
#     *   **projectName**: Om makarand heights
#     *   **location**: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
#     *   **price**: 14000000
#     *   **area**: 650.0 sq meter
#     *   **pincode**: 400075
#     *   **type**: 2BHK
#     *   **amenities**: Not specified
#
# ⚠️ Unmatched Points:
# *   The query asked for "apartments," and while the retrieved properties are of type "RESIDENTIAL" and have configurations like "1BHK" and "2BHK," the term "apartments" is not explicitly used in the property data.
#
# 💡 Explanation:
# The retrieved properties are located at "104, Yashvant Seth Jadhav Marg," which directly matches the user's location query. All properties listed are residential and have specific bedroom configurations (1BHK, 2BHK), which are typically considered apartments. However, the exact word "apartments" was not found in the data.
#
# 📚 CONTEXT USED:
#
# Document 1:
#  unique_property_id: cmfaycwy9003bvc189xf97r7w
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712593-25cd2d9a5765be22.jpg
# carpetArea: 354.0
# price: 790000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712594-cd33c56e7db9cd37.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs790000. having Area or carpet area: 354.0 sq meter. and also _ !.
#
# Document 2:
#  unique_property_id: cmfaycwy9003cvc181yx3c5gf
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 0.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712597-accd128a6ea12d10.jpg
# carpetArea: 391.0
# price: 880000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712598-d2ac8b8887119ad8.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs880000. having Area or carpet area: 391.0 sq meter. and also _ !.
#
# Document 3:
#  unique_property_id: cmfaycwy9003evc186uhex90a
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmfaycwy9003dvc1853ic14wb
# bathrooms: 2
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712599-4bd849d13fb20425.jpg
# carpetArea: 536.0
# price: 12000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712607-8e031215d719e572.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :2BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs12000000. having Area or carpet area: 536.0 sq meter. and also _ !.
#
# Document 4:
#  unique_property_id: cmfaycwy9003avc18vwkotg8q
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 1BHK
# configurationId: cmfaycwy80039vc18b1epdodx
# bathrooms: 1
# balcony: 1.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712590-57c98e762d3e95c3.jpg
# carpetArea: 379.0
# price: 850000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712591-aa79bad30786e10c.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :1BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs850000. having Area or carpet area: 379.0 sq meter. and also _ !.
#
# Document 5:
#  unique_property_id: cmfaycwy9003fvc1859euhuy7
# id_x: cmfaycwy70036vc18ppmb8mwh
# projectType: RESIDENTIAL
# projectName: Om makarand heights
# projectCategory: STANDALONE
# slug: om-makarand-heights-ashoknagar-chembur-mumbai-716337
# projectAge:
# projectSummary: _
# possessionDate: 2025-09-21 00:00:00
# id_y: cmfaycwya003hvc18yc5gtwtc
# landmark: Hind high school
# fullAddress: 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075
# pincode: 400075
# propertyCategory: RESIDENTIAL
# type: 2BHK
# configurationId: cmfaycwy9003dvc1853ic14wb
# bathrooms: 2
# balcony: 2.0
# furnishedType: UNFURNISHED
# furnishingType: []
# floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712608-05900f06f63a6dfa.jpg
# carpetArea: 650.0
# price: 14000000
# propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757325712608-e94b60550c5c2690.jpg"]
# lift: 0
# ready_to_move: 0
# context: Project Name: Om makarand heights and type :2BHK. Located at : 104, Yashvant Seth Jadhav Marg, Gauri Shankar Wadi No. 2, Savitribai Phule Nagar, Pant Nagar, Ghatkopar East, Mumbai, Maharashtra 400075 , near om-makarand-heights-ashoknagar-chembur-mumbai-716337 , having landmark :Hind high school Property Type: . Price: Rs14000000. having Area or carpet area: 650.0 sq meter. and also _ !.

# %%
from pydantic import BaseModel, Field
from typing import List, Optional

class PropertyMatch(BaseModel):
    id: str = Field(..., description="Unique property ID , with coulmn name unique_property_id")
    projectName: Optional[str] = Field(None, description="Name of the real estate project")
    location: Optional[str] = Field(None, description="Project location or address")
    price: Optional[str] = Field(None, description="Price or price range, where 1 crore or 1cr = 10000000")
    area: Optional[str] = Field(None, description="Total or built-up area details")
    pincode: Optional[str] = Field(None, description="Project pincode")
    type: Optional[str] = Field(None, description="Property type, e.g. apartment, villa, plot, etc.")
    landmark: Optional[str] = Field(None, description="Nearby landmark if available")
    amenities: Optional[str] = Field(None, description="Mentioned amenities if available")

class RAGAnswer(BaseModel):
    matching_projects: List[PropertyMatch] = Field(default_factory=list)
    unmatched_points: List[str] = Field(default_factory=list)
    explanation: str = Field(..., description="Reasoning or context explanation")

# %%
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import ChatPromptTemplate

parser = PydanticOutputParser(pydantic_object=RAGAnswer)

prompt = ChatPromptTemplate.from_template("""
You are a Real Estate Expert Assistant helping a user find matching properties.

You will be given retrieved property data (from embeddings) and a user query.

Your job:
1. Identify properties that match **all** conditions in the query.
2. Return your answer strictly as JSON according to the provided format instructions.
3. If some query conditions are not met, list them under `unmatched_points`.
4. Never assume data not present in the retrieved context.
5. If nothing matches, leave `matching_projects` empty and explain why.
6. if there is a limit for price range, make sure to follow it.

---
Retrieved Property Data:
{context}

User Query:
{question}

{format_instructions}
""")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    google_api_key=api_key,
    temperature=0.2
)

# Build the LangChain pipeline
rag_chain = (
    prompt
    | model
    | parser
)

# %%
query = "List projects with apartments near subhash nagar with lift"
results = db.similarity_search(query, k=5)

print(f"🔍 Retrieved {len(results)} most relevant property entries.\n")

context = "\n\n---\n\n".join([
    f"Property ID: {doc.metadata.get('unique_property_ID', 'Unknown')}\n{doc.page_content}"
    for doc in results
])

input_data = {
    "context": context,
    "question": query,
    "format_instructions": parser.get_format_instructions()
}
# Out:
# 🔍 Retrieved 5 most relevant property entries.

# %%
response = rag_chain.invoke(input_data)

# %%
from rich import print
from rich.panel import Panel
from rich.table import Table
print(response)
print("\n✅ [bold cyan]Matching Projects[/bold cyan]")
if response.matching_projects:
    table = Table(show_header=True, header_style="bold magenta")
    table.add_column("ID")
    table.add_column("Project Name")
    table.add_column("Location")
    table.add_column("Price")
    table.add_column("Area")
    table.add_column("Pincode")
    table.add_column("Type")
    table.add_column("Landmark")
    table.add_column("Amenities")

    for prop in response.matching_projects:
        table.add_row(
            prop.id or "-",
            prop.projectName or "-",
            prop.location or "-",
            prop.price or "-",
            prop.area or "-",
            prop.pincode or "-",
            prop.type or "-",
            prop.landmark or "-",
            prop.amenities or "-"
        )
    print(table)
else:
    print("[yellow]No matching projects found.[/yellow]")

print("\n⚠️ [bold yellow]Unmatched Points:[/bold yellow]", response.unmatched_points)
print("\n💡 [bold green]Explanation:[/bold green]", response.explanation)

# Reference cards (all docs used)
print("\n📚 [bold underline cyan]Referenced Property Data Cards:[/bold underline cyan]")
for i, doc in enumerate(results, 1):
    print(Panel(f"{doc.page_content}", title=f"Property {i}", expand=False))
# Out:
# RAGAnswer(
#     matching_projects=[
#         PropertyMatch(
#             id='cmff8vfoq0013vxp7h3onmg46',
#             projectName='Ashwini',
#             location='Mumbai chembur',
#             price='11111111',
#             area='123.0 sq meter',
#             pincode='411017',
#             type='1BHK',
#             landmark='Babys school',
#             amenities=None
#         ),
#         PropertyMatch(
#             id='cmfp02pgf0023vxxulf38fhsj',
#             projectName='testing',
#             location='asdfgh',
#             price='10088000',
#             area='9.79 sq meter',
#             pincode='123456',
#             type='5BHK',
#             landmark='sdfgb',
#             amenities=None
#         )
#     ],
#     unmatched_points=[],
#     explanation=''
# )
# ✅ Matching Projects
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ ID           ┃ Project Name ┃ Location     ┃ Price    ┃ Area         ┃ Pincode ┃ Type ┃ Landmark    ┃ Amenities ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ cmff8vfoq00… │ Ashwini      │ Mumbai       │ 11111111 │ 123.0 sq     │ 411017  │ 1BHK │ Babys       │ -         │
# │              │              │ chembur      │          │ meter        │         │      │ school      │           │
# │ cmfp02pgf00… │ testing      │ asdfgh       │ 10088000 │ 9.79 sq      │ 123456  │ 5BHK │ sdfgb       │ -         │
# │              │              │              │          │ meter        │         │      │             │           │
# └──────────────┴──────────────┴──────────────┴──────────┴──────────────┴─────────┴──────┴─────────────┴───────────┘
# ⚠️ Unmatched Points:
# []
# 💡 Explanation:
# 📚 Referenced Property Data Cards:
# ╭────────────────────────────────────────────────── Property 1 ───────────────────────────────────────────────────╮
# │ unique_property_id: cmfp02t6d002fvxxubqj69fmu                                                                   │
# │ id_x: cmff8swbm0001vxp7pe3neibi                                                                                 │
# │ projectType: RESIDENTIAL                                                                                        │
# │ projectName: testing                                                                                            │
# │ projectCategory: STANDALONE                                                                                     │
# │ slug: testing-modelcolony-shivajinagar-pune-301013                                                              │
# │ projectAge: 11.0                                                                                                │
# │ projectSummary: sdfghjhgfdfghjgfdfghgfgh                                                                        │
# │ possessionDate:                                                                                                 │
# │ id_y: cmff8swbn0007vxp7bhj7cmqv                                                                                 │
# │ landmark: sdfgb                                                                                                 │
# │ fullAddress: asdfgh                                                                                             │
# │ pincode: 123456                                                                                                 │
# │ propertyCategory: RESIDENTIAL                                                                                   │
# │ type: 2BHK                                                                                                      │
# │ configurationId: cmfozzj19001rvxxuloxiehen                                                                      │
# │ bathrooms: 10                                                                                                   │
# │ balcony: 2.0                                                                                                    │
# │ furnishedType: UNFURNISHED                                                                                      │
# │ furnishingType: []                                                                                              │
# │ floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758175122464-bb8651e2ee2d0642.png          │
# │ carpetArea: 3.0                                                                                                 │
# │ price: 120000000                                                                                                │
# │ propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758175122464-0dead4f474b5ccbc.jpg"]      │
# │ lift: 0                                                                                                         │
# │ ready_to_move: 1                                                                                                │
# │ context: Project Name: testing and type :2BHK. Located at : asdfgh , near                                       │
# │ testing-modelcolony-shivajinagar-pune-301013 , having landmark :sdfgb Property Type: . Price: Rs120000000.      │
# │ having Area or carpet area: 3.0 sq meter. and also sdfghjhgfdfghjgfdfghgfgh !.                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Property 2 ───────────────────────────────────────────────────╮
# │ unique_property_id: cmfw5ivrd0007vxnk9hpgpk3m                                                                   │
# │ id_x: cmfw5ivra0001vxnkbozvz8bd                                                                                 │
# │ projectType: RESIDENTIAL                                                                                        │
# │ projectName: testing igi                                                                                        │
# │ projectCategory: TOWNSHIP                                                                                       │
# │ slug: testing-igi-somwarpeth-camp-pune-541659                                                                   │
# │ projectAge: 8.0                                                                                                 │
# │ projectSummary: aqwsedrftgyhujikozsxdcfvgbhjnkm                                                                 │
# │ possessionDate:                                                                                                 │
# │ id_y: cmfw5ivre0009vxnkmzexw3zd                                                                                 │
# │ landmark: sedrftgyhuj                                                                                           │
# │ fullAddress: awsedrftgyhujk                                                                                     │
# │ pincode: 123456                                                                                                 │
# │ propertyCategory: RESIDENTIAL                                                                                   │
# │ type: 3BHK                                                                                                      │
# │ configurationId: cmfw5ivrd0006vxnk2bia4myh                                                                      │
# │ bathrooms: 99                                                                                                   │
# │ balcony: 88.0                                                                                                   │
# │ furnishedType: UNFURNISHED                                                                                      │
# │ furnishingType: []                                                                                              │
# │ floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758607532944-ac73972e2cdcdbfb.jpg          │
# │ carpetArea: 69.0                                                                                                │
# │ price: 960000000                                                                                                │
# │ propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758607532944-e10a4f6be6b3cc76.jpg"]      │
# │ lift: 0                                                                                                         │
# │ ready_to_move: 1                                                                                                │
# │ context: Project Name: testing igi and type :3BHK. Located at : awsedrftgyhujk , near                           │
# │ testing-igi-somwarpeth-camp-pune-541659 , having landmark :sedrftgyhuj Property Type: . Price: Rs960000000.     │
# │ having Area or carpet area: 69.0 sq meter. and also aqwsedrftgyhujikozsxdcfvgbhjnkm !.                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Property 3 ───────────────────────────────────────────────────╮
# │ unique_property_id: cmfp02t4b002dvxxu826dader                                                                   │
# │ id_x: cmff8swbm0001vxp7pe3neibi                                                                                 │
# │ projectType: RESIDENTIAL                                                                                        │
# │ projectName: testing                                                                                            │
# │ projectCategory: STANDALONE                                                                                     │
# │ slug: testing-modelcolony-shivajinagar-pune-301013                                                              │
# │ projectAge: 11.0                                                                                                │
# │ projectSummary: sdfghjhgfdfghjgfdfghgfgh                                                                        │
# │ possessionDate:                                                                                                 │
# │ id_y: cmff8swbn0007vxp7bhj7cmqv                                                                                 │
# │ landmark: sdfgb                                                                                                 │
# │ fullAddress: asdfgh                                                                                             │
# │ pincode: 123456                                                                                                 │
# │ propertyCategory: RESIDENTIAL                                                                                   │
# │ type: 2BHK                                                                                                      │
# │ configurationId: cmfozzj19001rvxxuloxiehen                                                                      │
# │ bathrooms: 99                                                                                                   │
# │ balcony: 987.0                                                                                                  │
# │ furnishedType: SEMI_FURNISHED                                                                                   │
# │ furnishingType: ["KITCHEN_APPLIANCES","BASIC_FURNITURE"]                                                        │
# │ floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174963753-1d59b6ee8bc63eff.jpg          │
# │ carpetArea: 9.0                                                                                                 │
# │ price: 980000000                                                                                                │
# │ propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174963765-07ee6ee92139cc03.jpeg"]     │
# │ lift: 0                                                                                                         │
# │ ready_to_move: 1                                                                                                │
# │ context: Project Name: testing and type :2BHK. Located at : asdfgh , near                                       │
# │ testing-modelcolony-shivajinagar-pune-301013 , having landmark :sdfgb Property Type: . Price: Rs980000000.      │
# │ having Area or carpet area: 9.0 sq meter. and also sdfghjhgfdfghjgfdfghgfgh !.                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Property 4 ───────────────────────────────────────────────────╮
# │ unique_property_id: cmff8vfoq0013vxp7h3onmg46                                                                   │
# │ id_x: cmf53kkzy000fvcu8tx8jwjmr                                                                                 │
# │ projectType: RESIDENTIAL                                                                                        │
# │ projectName: Ashwini                                                                                            │
# │ projectCategory: STANDALONE                                                                                     │
# │ slug: luxury-ashwini-ashoknagar-chembur-mumbai-675058                                                           │
# │ projectAge:                                                                                                     │
# │ projectSummary: _                                                                                               │
# │ possessionDate: 2025-09-28 00:00:00                                                                             │
# │ id_y: cmf53kl01000nvcu8ibut7fka                                                                                 │
# │ landmark: Babys school                                                                                          │
# │ fullAddress: Mumbai chembur                                                                                     │
# │ pincode: 411017                                                                                                 │
# │ propertyCategory: RESIDENTIAL                                                                                   │
# │ type: 1BHK                                                                                                      │
# │ configurationId: cmf53kkzz000ivcu89r5399s4                                                                      │
# │ bathrooms: 1                                                                                                    │
# │ balcony: 1.0                                                                                                    │
# │ furnishedType: UNFURNISHED                                                                                      │
# │ furnishingType: []                                                                                              │
# │ floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1757584023815-67012c27580e3e23.jpg          │
# │ carpetArea: 123.0                                                                                               │
# │ price: 11111111                                                                                                 │
# │ propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1756971672464-1e5179453b5df91d.jpg"]      │
# │ lift: 0                                                                                                         │
# │ ready_to_move: 0                                                                                                │
# │ context: Project Name: Ashwini and type :1BHK. Located at : Mumbai chembur , near                               │
# │ luxury-ashwini-ashoknagar-chembur-mumbai-675058 , having landmark :Babys school Property Type: . Price:         │
# │ Rs11111111. having Area or carpet area: 123.0 sq meter. and also _ !.                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Property 5 ───────────────────────────────────────────────────╮
# │ unique_property_id: cmfp02pgf0023vxxulf38fhsj                                                                   │
# │ id_x: cmff8swbm0001vxp7pe3neibi                                                                                 │
# │ projectType: RESIDENTIAL                                                                                        │
# │ projectName: testing                                                                                            │
# │ projectCategory: STANDALONE                                                                                     │
# │ slug: testing-modelcolony-shivajinagar-pune-301013                                                              │
# │ projectAge: 11.0                                                                                                │
# │ projectSummary: sdfghjhgfdfghjgfdfghgfgh                                                                        │
# │ possessionDate:                                                                                                 │
# │ id_y: cmff8swbn0007vxp7bhj7cmqv                                                                                 │
# │ landmark: sdfgb                                                                                                 │
# │ fullAddress: asdfgh                                                                                             │
# │ pincode: 123456                                                                                                 │
# │ propertyCategory: RESIDENTIAL                                                                                   │
# │ type: 5BHK                                                                                                      │
# │ configurationId: cmfozqxd90001vxxuau2xc6lj                                                                      │
# │ bathrooms: 8                                                                                                    │
# │ balcony: 8.0                                                                                                    │
# │ furnishedType: UNFURNISHED                                                                                      │
# │ furnishingType: []                                                                                              │
# │ floorPlanImage: https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174783708-6bab276d8a2b3207.jpg          │
# │ carpetArea: 9.79                                                                                                │
# │ price: 10088000                                                                                                 │
# │ propertyImages: ["https://pub-d28896f69c604ec5aa743cb0397740d9.r2.dev/1758174623697-27c4f71a991e078c.jpg"]      │
# │ lift: 0                                                                                                         │
# │ ready_to_move: 1                                                                                                │
# │ context: Project Name: testing and type :5BHK. Located at : asdfgh , near                                       │
# │ testing-modelcolony-shivajinagar-pune-301013 , having landmark :sdfgb Property Type: . Price: Rs10088000.       │
# │ having Area or carpet area: 9.79 sq meter. and also sdfghjhgfdfghjgfdfghgfgh !.                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
